# %%
import pandas as pd

# %%
car={'BRAND':['honda','audi','ford','maruthi'],
    'PRICE':[22000,20000,40000,35000]}

# %%
df=pd.DataFrame(car)

# %%
df
# Out:
#      BRAND  PRICE
# 0    honda  22000
# 1     audi  20000
# 2     ford  40000
# 3  maruthi  35000

# %% [markdown]
# ## TASK

# %%
mark={'NAME':['Abhimanyu','AJith','Akshay','Alen','Anand','Ansal','Arun kumar','ASwin','Dhavood','Haripriya','Indrajith','Jishnu vs','Jishnu Raj','Jopika','Keerthi','Kiran','Lubna','Mancy',
             'Merlin','Safeer','Siraj','Nandu','Najmi','Nida','Rahul','Ramshad','Sanika','Sanoy','Shammas','Smijith','Sneha','Soorya','Swathi',
             'Vidhya','Vishnu'],
      'PYTHON':[25,24,22,21,23,24,16,15,14,23,21,25,16,20,24,23,22,21,23,19,23,22,23,24,25,21,23,25,23,22,21,19,23,24,25],
      'STATISTICS':[21,22,23,24,25,25,23,25,25,24,21,21,25,23,25,23,21,22,19,19,18,23,24,25,21,23,22,23,21,24,22,25,24,22,18],
      'ENGLISH':[22,24,21,22,24,25,20,21,20,21,22,25,24,21,23,25,20,21,22,25,21,21,20,23,25,23,24,23,20,21,25,20,20,21,25]
      
     }

# %%
df=pd.DataFrame(mark)

# %%
df
# Out:
#           NAME  PYTHON  STATISTICS  ENGLISH
# 0    Abhimanyu      25          21       22
# 1        AJith      24          22       24
# 2       Akshay      22          23       21
# 3         Alen      21          24       22
# 4        Anand      23          25       24
# 5        Ansal      24          25       25
# 6   Arun kumar      16          23       20
# 7        ASwin      15          25       21
# 8      Dhavood      14          25       20
# 9    Haripriya      23          24       21
# 10   Indrajith      21          21       22
# 11   Jishnu vs      25          21       25
# 12  Jishnu Raj      16          25       24
# 13      Jopika      20          23       21
# 14     Keerthi      24          25       23
# 15       Kiran      23          23       25
# 16       Lubna      22          21       20
# 17       Mancy      21          22       21
# 18      Merlin      23          19       22
# 19      Safeer      19          19       25
# ...

# %%
df["TOTAL"]=df['PYTHON']+df['STATISTICS']+df["ENGLISH"]

# %%
df['PERCENTAGE']=((df['TOTAL']/75)*100).round(2)

# %%
df['TOTAL'].max()
# Out:
# 74

# %%
df['NAME'][df['TOTAL']==df['TOTAL'].max()]
# Out:
# 5    Ansal
# Name: NAME, dtype: object

# %%
df
# Out:
#           NAME  PYTHON  STATISTICS  ENGLISH  TOTAL  PERCENTAGE
# 0    Abhimanyu      25          21       22     68       90.67
# 1        AJith      24          22       24     70       93.33
# 2       Akshay      22          23       21     66       88.00
# 3         Alen      21          24       22     67       89.33
# 4        Anand      23          25       24     72       96.00
# 5        Ansal      24          25       25     74       98.67
# 6   Arun kumar      16          23       20     59       78.67
# 7        ASwin      15          25       21     61       81.33
# 8      Dhavood      14          25       20     59       78.67
# 9    Haripriya      23          24       21     68       90.67
# 10   Indrajith      21          21       22     64       85.33
# 11   Jishnu vs      25          21       25     71       94.67
# 12  Jishnu Raj      16          25       24     65       86.67
# 13      Jopika      20          23       21     64       85.33
# ...

# %%
df
# Out:
#           NAME  PYTHON  STATISTICS  ENGLISH  TOTAL  PERCENTAGE
# 0    Abhimanyu      25          21       22     68       90.67
# 1        AJith      24          22       24     70       93.33
# 2       Akshay      22          23       21     66       88.00
# 3         Alen      21          24       22     67       89.33
# 4        Anand      23          25       24     72       96.00
# 5        Ansal      24          25       25     74       98.67
# 6   Arun kumar      16          23       20     59       78.67
# 7        ASwin      15          25       21     61       81.33
# 8      Dhavood      14          25       20     59       78.67
# 9    Haripriya      23          24       21     68       90.67
# 10   Indrajith      21          21       22     64       85.33
# 11   Jishnu vs      25          21       25     71       94.67
# 12  Jishnu Raj      16          25       24     65       86.67
# 13      Jopika      20          23       21     64       85.33
# ...

# %%
df[df['NAME']==0df['TOTAL'].max()]
# Out:
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_7352\1278819326.py", line 1
#     df[df['NAME']==0df['TOTAL'].max()]
#                     ^
# SyntaxError: invalid syntax

# %%
df.info()

# %%
df.drop(column['PERCENTAGE'])

# %%
df

# %%
mark={'NAME':['Abhimanyu','AJith','Akshay','Alen','Anand','Ansal','Arun kumar','ASwin','Dhavood','Haripriya','Indrajith','Jishnu vs','Jishnu Raj','Jopika','Keerthi','Kiran','Lubna','Mancy',

# %%
df=pd.read_csv("netflix-titles_2021.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7352\1927981077.py in <module>
# ----> 1 df=pd.read_csv("netflix-titles_2021.csv")
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
